# %% [markdown]
# ## Data

# %%
# Out:
#             x           y
# 0   10.000000   34.967142
# 1   10.816327   31.066337
# ..        ...         ...
# 48  49.183673  150.987203
# 49  50.000000  132.369598
#
# [50 rows x 2 columns]

# %% [markdown]
# ## Linear regression
#
# ### Fit

# %%
# Out:
# LinearRegression()

# %% [markdown]
# #### Coefficients

# %%
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['x'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([2.8550415]),
#  'rank_': 1,
#  'singular_': array([83.29931278]),
#  'intercept_': 2.0940159093253072}

# %% [markdown]
# ### Predictions

# %% [markdown]
# #### Calculate
#
# Use optimized numbers from mathematical equation to calculate predictions.

# %%
# Out:
# array([ 30.64443092,  32.97507705,  35.30572317,  37.63636929,
#         39.96701542,  42.29766154,  44.62830766,  46.95895379,
#         49.28959991,  51.62024603,  53.95089216,  56.28153828,
#         58.6121844 ,  60.94283053,  63.27347665,  65.60412277,
#         67.9347689 ,  70.26541502,  72.59606114,  74.92670727,
#         77.25735339,  79.58799952,  81.91864564,  84.24929176,
#         86.57993789,  88.91058401,  91.24123013,  93.57187626,
#         95.90252238,  98.2331685 , 100.56381463, 102.89446075,
#        105.22510687, 107.555753  , 109.88639912, 112.21704524,
#        114.54769137, 116.87833749, 119.20898361, 121.53962974,
#        123.87027586, 126.20092198, 128.53156811, 130.86221423,
#        133.19286036, 135.52350648, 137.8541526 , 140.18479873,
#        142.51544485, 144.84609097])

# %%
# Out:
#             x           y      y_pred
# 0   10.000000   34.967142   30.644431
# 1   10.816327   31.066337   32.975077
# ..        ...         ...         ...
# 48  49.183673  150.987203  142.515445
# 49  50.000000  132.369598  144.846091
#
# [50 rows x 3 columns]

# %% [markdown]
# #### Plot
#
# ##### Basic

# %% [markdown]
# ##### Custom

# %% [markdown]
# ### Evaluate
#
# The prediction is not perfect because there is a difference between predicted and actual values; ie. error.

# %% [markdown]
# #### Calculate R-squared

# %%
# Out:
#             x           y      y_pred      error      error2
# 0   10.000000   34.967142   30.644431   4.322711   18.685827
# 1   10.816327   31.066337   32.975077  -1.908740    3.643290
# ..        ...         ...         ...        ...         ...
# 48  49.183673  150.987203  142.515445   8.471758   71.770691
# 49  50.000000  132.369598  144.846091 -12.476493  155.662866
#
# [50 rows x 5 columns]

# %%
# Out:
# 9.083731585153524

# %%
# Out:
# 0.9333745996499732

# %% [markdown]
# #### Plot

# %%
# Out:
# '$y = 2.86x + 2.09$'

# %%
# Out:
# '$R^2: 0.933$'

# %%
# Out:
# '$y = 2.86x + 2.09$\n$R^2: 0.933$'

# %%
# Out:
#   Cell In[23], line 3
#     1. Linearity
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Two variables
#
# 1. Categorical
# 2. Create facet plot

# %% [markdown]
# ## Linear regression details
#
# ### Fit

# %% [markdown]
# ### Coefficients

# %%
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.931
# Method:                 Least Squares   F-statistic:                     658.0
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):           1.13e-29
# Time:                        13:48:56   Log-Likelihood:                -181.27
# No. Observations:                  50   AIC:                             366.5
# Df Residuals:                      48   BIC:                             370.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.0940      3.587      0.584      0.562      -5.118       9.306
# ...

# %% [markdown]
# ## Predictions
#
# ### Calculate

# %%
# Out:
# array([ 30.64443092,  32.97507705,  35.30572317,  37.63636929,
#         39.96701542,  42.29766154,  44.62830766,  46.95895379,
#         49.28959991,  51.62024603,  53.95089216,  56.28153828,
#         58.6121844 ,  60.94283053,  63.27347665,  65.60412277,
#         67.9347689 ,  70.26541502,  72.59606114,  74.92670727,
#         77.25735339,  79.58799952,  81.91864564,  84.24929176,
#         86.57993789,  88.91058401,  91.24123013,  93.57187626,
#         95.90252238,  98.2331685 , 100.56381463, 102.89446075,
#        105.22510687, 107.555753  , 109.88639912, 112.21704524,
#        114.54769137, 116.87833749, 119.20898361, 121.53962974,
#        123.87027586, 126.20092198, 128.53156811, 130.86221423,
#        133.19286036, 135.52350648, 137.8541526 , 140.18479873,
#        142.51544485, 144.84609097])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 model.slope
#
# File ~/miniforge3/envs/work/lib/python3.12/site-packages/statsmodels/base/wrapper.py:34, in ResultsWrapper.__getattribute__(self, attr)
#      31 except AttributeError:
#      32     pass
# ---> 34 obj = getattr(results, attr)
#      35 data = results.model.data
#      36 how = self._wrap_attrs.get(attr)
#
# AttributeError: 'OLSResults' object has no attribute 'slope'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 model.intercept
#
# File ~/miniforge3/envs/work/lib/python3.12/site-packages/statsmodels/base/wrapper.py:34, in ResultsWrapper.__getattribute__(self, attr)
#      31 except AttributeError:
#      32     pass
# ---> 34 obj = getattr(results, attr)
#      35 data = results.model.data
#      36 how = self._wrap_attrs.get(attr)
#
# AttributeError: 'OLSResults' object has no attribute 'intercept'

# %%
# Out:
# LinregressResult(slope=2.855041501270444, intercept=2.094015909325293, rvalue=0.9654091866157137, pvalue=1.12627638267806e-29, stderr=0.11129797373928282, intercept_stderr=3.587138200446792)

# %% [markdown]
# ## Generate data

# %%
# Out:
# array([21857.51186511, 25276.81539986, 23104.58646384, ...,
#        23650.04341546, 22935.25799712, 26098.49987184])

# %% [markdown]
# - Goal: template to create plots with matplotlib titles
# - Assume people will use it as a reference starting from a dataframe

# %% [markdown]
# ## Histogram plot

# %% [markdown]
# ### Basic

# %% [markdown]
# ### Customize

# %% [markdown]
# #### Change color

# %% [markdown]
# #### Add more bins

# %% [markdown]
# #### Add border to bins

# %% [markdown]
# #### Add title

# %% [markdown]
# #### Add axis labels

# %% [markdown]
# ## Scatter plot
#
# Two variables:
#
# - `x`
# - `y`

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 plt.scatter()
#
# TypeError: scatter() missing 2 required positional arguments: 'x' and 'y'

# %% [markdown]
# ### Prepare data

# %% [markdown]
# #### Transform salary `array` to `DataFrame`

# %%
# Out:
#             salary
# 0     26648.167939
# 1     25229.835439
# ...            ...
# 9998  26915.083868
# 9999  26867.495219
#
# [10000 rows x 1 columns]

# %% [markdown]
# #### Add new variable

# %%
# Out:
#             salary  experience
# 0     26648.167939    6.456207
# 1     25229.835439   11.273740
# ...            ...         ...
# 9998  26915.083868   11.634972
# 9999  26867.495219    6.764179
#
# [10000 rows x 2 columns]

# %% [markdown]
# ### Scatter plot

# %% [markdown]
# ## Practical case on real data

# %% [markdown]
# ### Load data from file

# %%
# Out:
#          country continent  year  life_expectancy  population  gdp_per_cap  \
# 0    Afghanistan      Asia  2007           43.828    31889923   974.580338
# 1        Albania    Europe  2007           76.423     3600523  5937.029526
# ..           ...       ...   ...              ...         ...          ...
# 140       Zambia    Africa  2007           42.384    11746035  1271.211593
# 141     Zimbabwe    Africa  2007           43.487    12311143   469.709298
#
#     iso_alpha  iso_num
# 0         AFG        4
# 1         ALB        8
# ..        ...      ...
# 140       ZMB      894
# 141       ZWE      716
#
# [142 rows x 8 columns]

# %% [markdown]
# ### Scatter plot

# %% [markdown]
# ## Seaborn

# %% [markdown]
# ### Scatter plot
#
# #### Basic

# %% [markdown]
# ### Customize plot
#
# #### Color palette

# %%
# Out:
# ['magma',
#  'inferno',
#  'plasma',
#  'viridis',
#  'cividis',
#  'twilight',
#  'twilight_shifted',
#  'turbo',
#  'Blues',
#  'BrBG',
#  'BuGn',
#  'BuPu',
#  'CMRmap',
#  'GnBu',
#  'Greens',
#  'Greys',
#  'OrRd',
#  'Oranges',
#  'PRGn',
#  'PiYG',
#  'PuBu',
#  'PuBuGn',
#  'PuOr',
#  'PuRd',
#  'Purples',
#  'RdBu',
#  'RdGy',
#  'RdPu',
#  'RdYlBu',
#  'RdYlGn',
#  'Reds',
#  'Spectral',
#  'Wistia',
#  'YlGn',
#  'YlGnBu',
#  'YlOrBr',
#  'YlOrRd',
#  'afmhot',
#  'autumn',
#  'binary',
#  'bone',
#  'brg',
#  'bwr',
#  'cool',
#  'coolwarm',
#  'copper',
#  'cubehelix',
#  'flag',
#  'gist_earth',
#  'gist_gray',
#  'gist_heat',
#  'gist_ncar',
#  'gist_rainbow',
#  'gist_stern',
#  'gist_yarg',
#  'gnuplot',
#  'gnuplot2',
#  'gray',
#  'hot',
#  'hsv',
#  'jet',
#  'nipy_spectral',
#  'ocean',
#  'pink',
#  'prism',
#  'rainbow',
#  'seismic',
#  'spring',
#  'summer',
#  'terrain',
#  'winter',
#  'Accent',
#  'Dark2',
#  'Paired',
#  'Pastel1',
#  'Pastel2',
# ...

# %% [markdown]
# ## Plotly

# %% [markdown]
# ### Load data

# %%
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# ...       ...
# 1702      716
# 1703      716
#
# [1704 rows x 8 columns]

# %% [markdown]
# ### Scatter plot

# %% [markdown]
# #### Basic

# %% [markdown]
# #### Custom
