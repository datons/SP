# %% [markdown]
# # Multiple linear regression with one categorical variable

# %% [markdown]
# ## Load data

# %% [markdown]
# ## Feature selection

# %% [markdown]
# ## Linear regression
#
# ### Fit

# %%
# Out:
# 'y_target ~ x_numeric + C(x_categorical)'

# %%
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               y_target   R-squared:                       0.927
# Model:                            OLS   Adj. R-squared:                  0.926
# Method:                 Least Squares   F-statistic:                     4193.
# Date:                Sun, 27 Oct 2024   Prob (F-statistic):               0.00
# Time:                        14:40:08   Log-Likelihood:                -3711.2
# No. Observations:                1000   AIC:                             7430.
# Df Residuals:                     996   BIC:                             7450.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -0.8213      0.973     -0.844      0.399      -2.730       1.087
# C(x_categorical)[T.low]        0.4991      0.765      0.652      0.515      -1.003       2.001
# C(x_categorical)[T.medium]     0.2233      0.781      0.286      0.775      -1.310       1.757
# x_numeric                      3.0428      0.027    112.073      0.000       2.989       3.096
# ==============================================================================
# Omnibus:                        0.498   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.780   Jarque-Bera (JB):                0.584
# Skew:                           0.008   Prob(JB):                        0.747
# Kurtosis:                       2.883   Cond. No.                         119.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Formula

# %%
# Out:
# Intercept                    -0.821277
# C(x_categorical)[T.low]       0.499087
# C(x_categorical)[T.medium]    0.223293
# x_numeric                     3.042771
# dtype: float64

# %%
# Out:
# ['-0.82 \\cdot (Intercept)',
#  '0.50 \\cdot (C(x\\_categorical)[T.low])',
#  '0.22 \\cdot (C(x\\_categorical)[T.medium])',
#  '3.04 \\cdot (x\\_numeric)']

# %%
# Out:
# '$y = -0.82 \\cdot (Intercept) + 0.50 \\cdot (C(x\\_categorical)[T.low]) + 0.22 \\cdot (C(x\\_categorical)[T.medium]) + 3.04 \\cdot (x\\_numeric)$'

# %% [markdown]
# ### Predictions
# Use optimized numbers from mathematical equation to calculate predictions.

# %%
# Out:
#      x_numeric x_categorical
# 0     10.00000          high
# 1     10.04004           low
# ..         ...           ...
# 998   49.95996          high
# 999   50.00000           low
#
# [1000 rows x 2 columns]

# %%
# Out:
#      x_numeric x_categorical    y_target      y_pred
# 0     10.00000          high   30.485216   29.606436
# 1     10.04004           low   21.810619   30.227356
# ..         ...           ...         ...         ...
# 998   49.95996          high  156.843754  151.195459
# 999   50.00000           low  159.553052  151.816379
#
# [1000 rows x 4 columns]

# %% [markdown]
# ### Evaluate: R-squared
#
# The prediction is not perfect because there is a difference between predicted and actual values; ie. error.

# %%
# Out:
#      x_numeric x_categorical    y_target      y_pred     error     error2
# 0     10.00000          high   30.485216   29.606436  0.878780   0.772254
# 1     10.04004           low   21.810619   30.227356 -8.416737  70.841464
# ..         ...           ...         ...         ...       ...        ...
# 998   49.95996          high  156.843754  151.195459  5.648295  31.903240
# 999   50.00000           low  159.553052  151.816379  7.736673  59.856114
#
# [1000 rows x 6 columns]

# %%
# Out:
# 9.897675331791723

# %%
# Out:
# 0.9267104144706914

# %% [markdown]
# ### Interpretation

# %%
# Out:
# 9.897675331791723

# %% [markdown]
# $$
# \text{RMSE} = \sigma = \sqrt{\frac{1}{N}\sum_{i=1}^{N}(y_i - \hat{y}_i)^2}
# $$

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/3/3a/Standard_deviation_diagram_micro.svg" style="background-color:white;">

# %% [markdown]
# ### Visualize

# %%
# Out:
# '$y = -0.82 \\cdot (Intercept) + 0.50 \\cdot (C(x\\_categorical)[T.low]) + 0.22 \\cdot (C(x\\_categorical)[T.medium]) + 3.04 \\cdot (x\\_numeric)$\nRMSE = 9.90\nR2 = 0.93'

# %%
# Out:
# x_categorical
# low       355
# medium    326
# high      319
# Name: count, dtype: int64

# %%
# Out:
# 3

# %% [markdown]
# ### Assumptions
#
# 1. Linearity
# 2. Independence
# 3. Normality
# 4. Equal variance
# 5. No multicollinearity

# %% [markdown]
# #### Normality of residuals

# %% [markdown]
# 1. **Shapiro-Wilk Test**
#
#    - **When**: Small to moderate sample sizes (n < 2000).
#    - **Why**: Powerful for detecting general deviations from normality.
#    - **Example**: Small experimental datasets in psychology or biology.
#
# 2. **Kolmogorov-Smirnov (K-S) Test**
#
#    - **When**: Large sample sizes (n > 2000).
#    - **Why**: Good for general normality checks, particularly in large datasets.
#    - **Example**: Large survey or population data.
#
# 3. **Anderson-Darling Test**
#
#    - **When**: Concerned about deviations in the tails of the distribution.
#    - **Why**: More sensitive to issues in the tails than other tests.
#    - **Example**: Financial data with potential outliers.
#
# 4. **D’Agostino and Pearson’s Test**
#
#    - **When**: Interested in skewness or kurtosis.
#    - **Why**: Tests for both skewness and kurtosis (asymmetry and peakedness).
#    - **Example**: Social science or psychology data where the shape of the distribution matters.

# %%
# Out:
# Shapiro-Wilk Test statistic: 0.9983, p-value: 0.4304

# %% [markdown]
# #### Residuals vs. Predictions
#
# A residual plot helps detect non-linear relationships by plotting the residuals (errors) against the predicted (fitted) values. If the relationship is linear, the residuals should be randomly scattered around zero, with no distinct pattern. Any visible pattern, such as a curve or funnel shape, suggests non-linearity.

# %% [markdown]
# #### Homoscedasticity (Equal variance)

# %% [markdown]
# The Breusch-Pagan test examines whether the variance of the residuals is dependent on the fitted values. The null hypothesis is that the residuals are homoscedastic (i.e., their variance is constant).

# %%
# Out:
#                                Breusch-Pagan test
# Lagrange multiplier statistic            7.238497
# p-value                                  0.064672
# F-value                                  2.420703
# F p-value                                0.064647

# %% [markdown]
# Interpretation:
# - p-value > 0.05: Fail to reject the null hypothesis (assume homoscedasticity).
# - p-value < 0.05: Reject the null hypothesis, indicating heteroscedasticity.

# %% [markdown]
# #### Multicollinearity

# %%
# Out:
# <style type="text/css">
# </style>
# <table id="T_31346">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31346_level0_col0" class="col_heading level0 col0" >VIF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31346_level0_row0" class="row_heading level0 row0" >const</th>
#       <td id="T_31346_row0_col0" class="data row0 col0" >9.413905</td>
#     </tr>
#     <tr>
#       <th id="T_31346_level0_row1" class="row_heading level0 row1" >x_numeric</th>
#       <td id="T_31346_row1_col0" class="data row1 col0" >1.001227</td>
#     </tr>
#     <tr>
#       <th id="T_31346_level0_row2" class="row_heading level0 row2" >x_categorical_low</th>
#       <td id="T_31346_row2_col0" class="data row2 col0" >1.363971</td>
#     </tr>
#     <tr>
#       <th id="T_31346_level0_row3" class="row_heading level0 row3" >x_categorical_medium</th>
#       <td id="T_31346_row3_col0" class="data row3 col0" >1.364138</td>
#     </tr>
#   </tbody>
# </table>
