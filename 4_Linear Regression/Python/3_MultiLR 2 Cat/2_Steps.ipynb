# %% [markdown]
# # Multiple linear regression with one categorical variable

# %% [markdown]
# ## Load data

# %%
# Out:
#      x_numeric x_categorical1 x_categorical2    y_target
# 0     10.00000           high        method3   46.715202
# 1     10.04004            low        method3   28.079814
# ..         ...            ...            ...         ...
# 998   49.95996           high        method3  135.106599
# 999   50.00000            low        method3  152.577609
#
# [1000 rows x 4 columns]

# %% [markdown]
# ## Feature selection

# %% [markdown]
# ## Linear regression
#
# ### Fit

# %%
# Out:
# 'y_target ~ x_numeric + C(x_categorical1) + C(x_categorical2)'

# %%
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               y_target   R-squared:                       0.924
# Model:                            OLS   Adj. R-squared:                  0.923
# Method:                 Least Squares   F-statistic:                     2407.
# Date:                Sun, 27 Oct 2024   Prob (F-statistic):               0.00
# Time:                        14:47:04   Log-Likelihood:                -3714.2
# No. Observations:                1000   AIC:                             7440.
# Df Residuals:                     994   BIC:                             7470.
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        1.2489      1.073      1.164      0.245      -0.857       3.354
# C(x_categorical1)[T.low]        -1.2412      0.769     -1.615      0.107      -2.750       0.267
# C(x_categorical1)[T.medium]     -0.5352      0.785     -0.682      0.495      -2.075       1.005
# C(x_categorical2)[T.method2]    -0.6733      0.771     -0.873      0.383      -2.187       0.840
# C(x_categorical2)[T.method3]     0.2489      0.771      0.323      0.747      -1.265       1.762
# x_numeric                        2.9899      0.027    109.660      0.000       2.936       3.043
# ==============================================================================
# Omnibus:                        0.719   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.698   Jarque-Bera (JB):                0.803
# Skew:                          -0.050   Prob(JB):                        0.669
# Kurtosis:                       2.904   Cond. No.                         130.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Formula

# %%
# Out:
# Intercept                       1.248859
# C(x_categorical1)[T.low]       -1.241247
#                                   ...
# C(x_categorical2)[T.method3]    0.248877
# x_numeric                       2.989942
# Length: 6, dtype: float64

# %%
# Out:
# ['1.25 \\cdot (Intercept)',
#  '-1.24 \\cdot (C(x\\_categorical1)[T.low])',
#  '-0.54 \\cdot (C(x\\_categorical1)[T.medium])',
#  '-0.67 \\cdot (C(x\\_categorical2)[T.method2])',
#  '0.25 \\cdot (C(x\\_categorical2)[T.method3])',
#  '2.99 \\cdot (x\\_numeric)']

# %%
# Out:
# '$y = 1.25 \\cdot (Intercept) + -1.24 \\cdot (C(x\\_categorical1)[T.low]) + -0.54 \\cdot (C(x\\_categorical1)[T.medium]) + -0.67 \\cdot (C(x\\_categorical2)[T.method2]) + 0.25 \\cdot (C(x\\_categorical2)[T.method3]) + 2.99 \\cdot (x\\_numeric)$'

# %% [markdown]
# ### Predictions
# Use optimized numbers from mathematical equation to calculate predictions.

# %%
# Out:
#      x_numeric x_categorical1 x_categorical2
# 0     10.00000           high        method3
# 1     10.04004            low        method3
# ..         ...            ...            ...
# 998   49.95996           high        method3
# 999   50.00000            low        method3
#
# [1000 rows x 3 columns]

# %%
# Out:
#      x_numeric x_categorical1 x_categorical2    y_target      y_pred
# 0     10.00000           high        method3   46.715202   31.397157
# 1     10.04004            low        method3   28.079814   30.275627
# ..         ...            ...            ...         ...         ...
# 998   49.95996           high        method3  135.106599  150.875123
# 999   50.00000            low        method3  152.577609  149.753594
#
# [1000 rows x 5 columns]

# %% [markdown]
# ### Evaluate: R-squared
#
# The prediction is not perfect because there is a difference between predicted and actual values; ie. error.

# %%
# Out:
#      x_numeric x_categorical1 x_categorical2    y_target      y_pred  \
# 0     10.00000           high        method3   46.715202   31.397157
# 1     10.04004            low        method3   28.079814   30.275627
# ..         ...            ...            ...         ...         ...
# 998   49.95996           high        method3  135.106599  150.875123
# 999   50.00000            low        method3  152.577609  149.753594
#
#          error      error2
# 0    15.318046  234.642520
# 1    -2.195813    4.821594
# ..         ...         ...
# 998 -15.768524  248.646345
# 999   2.824015    7.975061
#
# [1000 rows x 7 columns]

# %%
# Out:
# 9.92704514926918

# %%
# Out:
# 0.9237877636908809

# %% [markdown]
# ### Interpretation

# %%
# Out:
# 9.92704514926918

# %% [markdown]
# $$
# \text{RMSE} = \sigma = \sqrt{\frac{1}{N}\sum_{i=1}^{N}(y_i - \hat{y}_i)^2}
# $$

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/3/3a/Standard_deviation_diagram_micro.svg" style="background-color:white;">

# %% [markdown]
# ### Visualize

# %%
# Out:
# '$y = 1.25 \\cdot (Intercept) + -1.24 \\cdot (C(x\\_categorical1)[T.low]) + -0.54 \\cdot (C(x\\_categorical1)[T.medium]) + -0.67 \\cdot (C(x\\_categorical2)[T.method2]) + 0.25 \\cdot (C(x\\_categorical2)[T.method3]) + 2.99 \\cdot (x\\_numeric)$\nRMSE = 9.93\nR2 = 0.92'

# %%
# Out:
# x_categorical1  x_categorical2
# low             method2           125
#                 method1           118
#                                  ...
# high            method3           106
# medium          method2           102
# Name: count, Length: 9, dtype: int64

# %% [markdown]
# ### Assumptions
#
# 1. Linearity
# 2. Independence
# 3. Normality
# 4. Equal variance
# 5. No multicollinearity

# %% [markdown]
# #### Normality of residuals

# %% [markdown]
# 1. **Shapiro-Wilk Test**
#
#    - **When**: Small to moderate sample sizes (n < 2000).
#    - **Why**: Powerful for detecting general deviations from normality.
#    - **Example**: Small experimental datasets in psychology or biology.
#
# 2. **Kolmogorov-Smirnov (K-S) Test**
#
#    - **When**: Large sample sizes (n > 2000).
#    - **Why**: Good for general normality checks, particularly in large datasets.
#    - **Example**: Large survey or population data.
#
# 3. **Anderson-Darling Test**
#
#    - **When**: Concerned about deviations in the tails of the distribution.
#    - **Why**: More sensitive to issues in the tails than other tests.
#    - **Example**: Financial data with potential outliers.
#
# 4. **D’Agostino and Pearson’s Test**
#
#    - **When**: Interested in skewness or kurtosis.
#    - **Why**: Tests for both skewness and kurtosis (asymmetry and peakedness).
#    - **Example**: Social science or psychology data where the shape of the distribution matters.

# %%
# Out:
# Shapiro-Wilk Test statistic: 0.9992, p-value: 0.9453

# %% [markdown]
# #### Residuals vs. Predictions
#
# A residual plot helps detect non-linear relationships by plotting the residuals (errors) against the predicted (fitted) values. If the relationship is linear, the residuals should be randomly scattered around zero, with no distinct pattern. Any visible pattern, such as a curve or funnel shape, suggests non-linearity.

# %% [markdown]
# #### Homoscedasticity (Equal variance)

# %% [markdown]
# The Breusch-Pagan test examines whether the variance of the residuals is dependent on the fitted values. The null hypothesis is that the residuals are homoscedastic (i.e., their variance is constant).

# %%
# Out:
#                                Breusch-Pagan test
# Lagrange multiplier statistic            3.557229
# p-value                                  0.614746
# F-value                                  0.709702
# F p-value                                0.616208

# %% [markdown]
# Interpretation:
# - p-value > 0.05: Fail to reject the null hypothesis (assume homoscedasticity).
# - p-value < 0.05: Reject the null hypothesis, indicating heteroscedasticity.

# %% [markdown]
# #### Multicollinearity

# %%
# Out:
# <style type="text/css">
# </style>
# <table id="T_19873">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19873_level0_col0" class="col_heading level0 col0" >VIF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19873_level0_row0" class="row_heading level0 row0" >const</th>
#       <td id="T_19873_row0_col0" class="data row0 col0" >11.410908</td>
#     </tr>
#     <tr>
#       <th id="T_19873_level0_row1" class="row_heading level0 row1" >x_numeric</th>
#       <td id="T_19873_row1_col0" class="data row1 col0" >1.001811</td>
#     </tr>
#     <tr>
#       <th id="T_19873_level0_row2" class="row_heading level0 row2" >x_categorical1_low</th>
#       <td id="T_19873_row2_col0" class="data row2 col0" >1.364408</td>
#     </tr>
#     <tr>
#       <th id="T_19873_level0_row3" class="row_heading level0 row3" >x_categorical1_medium</th>
#       <td id="T_19873_row3_col0" class="data row3 col0" >1.364706</td>
#     </tr>
#     <tr>
#       <th id="T_19873_level0_row4" class="row_heading level0 row4" >x_categorical2_method2</th>
#       <td id="T_19873_row4_col0" class="data row4 col0" >1.332750</td>
#     </tr>
#     <tr>
#       <th id="T_19873_level0_row5" class="row_heading level0 row5" >x_categorical2_method3</th>
#       <td id="T_19873_row5_col0" class="data row5 col0" >1.332659</td>
#     </tr>
#   </tbody>
# </table>
